# %%
Orders = [
    {"order_id" :10, "customer": "aswathi",
     "item":"tv", "quantity":1,
     "price_per_item": 10000.0, "order_date":"2025-10-21"},
    {"order_id" :20, "customer": "anu",
     "item":"phone", "quantity":3,
     "price_per_item": 20000.0, "order_date":"2025-10-22"},
    {"order_id" :30, "customer": "Paul",
     "item":"laptop", "quantity":2,
     "price_per_item": 15000.0, "order_date":"2025-10-23"},
    {"order_id" :40, "customer": "Alice",
     "item":"phone", "quantity":1,
     "price_per_item": 18000.0, "order_date":"2025-10-2"},
    {"order_id" :50, "customer": "Arya",
     "item":"Headphones", "quantity":2,
     "price_per_item": 26000.0, "order_date":"2025-10-24"},
    {"order_id" :60, "customer": "David",
     "item":"keyboard", "quantity":2,
     "price_per_item": 19000.0, "order_date":"2025-10-25"},
    {"order_id" :70, "customer": "jack",
     "item":"USB cable", "quantity":1,
     "price_per_item": 290.0, "order_date":"2025-10-21"},
    {"order_id" :80, "customer": "julie",
     "item":"Monitar", "quantity":3,
     "price_per_item": 9000.0, "order_date":"2025-10-28"},
    {"order_id" :90, "customer": "Helen",
     "item":"Power bank", "quantity":1,
     "price_per_item": 45000.0, "order_date":"2025-10-23"},
    {"order_id" :100, "customer": "sidd",
     "item":"keyboard", "quantity":3,
     "price_per_item": 5000.0, "order_date":"2025-10-27"},

]
print("Dataset:")
for o in Orders:
  print(o)
# Out:
# Dataset:
# {'order_id': 10, 'customer': 'aswathi', 'item': 'tv', 'quantity': 1, 'price_per_item': 10000.0, 'order_date': '2025-10-21'}
# {'order_id': 20, 'customer': 'anu', 'item': 'phone', 'quantity': 3, 'price_per_item': 20000.0, 'order_date': '2025-10-22'}
# {'order_id': 30, 'customer': 'Paul', 'item': 'laptop', 'quantity': 2, 'price_per_item': 15000.0, 'order_date': '2025-10-23'}
# {'order_id': 40, 'customer': 'Alice', 'item': 'phone', 'quantity': 1, 'price_per_item': 18000.0, 'order_date': '2025-10-2'}
# {'order_id': 50, 'customer': 'Arya', 'item': 'Headphones', 'quantity': 2, 'price_per_item': 26000.0, 'order_date': '2025-10-24'}
# {'order_id': 60, 'customer': 'David', 'item': 'keyboard', 'quantity': 2, 'price_per_item': 19000.0, 'order_date': '2025-10-25'}
# {'order_id': 70, 'customer': 'jack', 'item': 'USB cable', 'quantity': 1, 'price_per_item': 290.0, 'order_date': '2025-10-21'}
# ...

# %% [markdown]
# ##2.1

# %%
total_revenue = 0
for o in Orders:
  total = o["quantity"]* o["price_per_item"]
  total_revenue = total_revenue + total

print("Total_revenue:", total_revenue)
# Out:
# Total_revenue: 295290.0

# %% [markdown]
# ##2.2

# %%
high_value_Orders = []
for o in Orders:
  total_value = o["quantity"] * o["price_per_item"]

  if total_value > 2000:
    high_value_Orders.append(o)

print(high_value_Orders)
# Out:
# [{'order_id': 10, 'customer': 'aswathi', 'item': 'tv', 'quantity': 1, 'price_per_item': 10000.0, 'order_date': '2025-10-21'}, {'order_id': 20, 'customer': 'anu', 'item': 'phone', 'quantity': 3, 'price_per_item': 20000.0, 'order_date': '2025-10-22'}, {'order_id': 30, 'customer': 'Paul', 'item': 'laptop', 'quantity': 2, 'price_per_item': 15000.0, 'order_date': '2025-10-23'}, {'order_id': 40, 'customer': 'Alice', 'item': 'phone', 'quantity': 1, 'price_per_item': 18000.0, 'order_date': '2025-10-2'}, {'order_id': 50, 'customer': 'Arya', 'item': 'Headphones', 'quantity': 2, 'price_per_item': 26000.0, 'order_date': '2025-10-24'}, {'order_id': 60, 'customer': 'David', 'item': 'keyboard', 'quantity': 2, 'price_per_item': 19000.0, 'order_date': '2025-10-25'}, {'order_id': 80, 'customer': 'julie', 'item': 'Monitar', 'quantity': 3, 'price_per_item': 9000.0, 'order_date': '2025-10-28'}, {'order_id': 90, 'customer': 'Helen', 'item': 'Power bank', 'quantity': 1, 'price_per_item': 45000.0, 'order_da
# ...

# %% [markdown]
# ##2.3

# %%
max_item = None
max_quantity = 0

for o in Orders:
  if o['quantity'] > max_quantity:
    max_quantity =o['quantity']
    max_item = o['quantity']

print("Highest total quantity sold:", max_item)
print("Total quantity:", max_quantity)
# Out:
# Highest total quantity sold: 3
# Total quantity: 3

# %% [markdown]
# ##3.1

# %%
def apply_discount(ordres , discount_rate):

  discount_orders = []

  for order in Orders:
    new_orders = order.copy()

    new_orders["price_per_item"] = order["price_per_item"] *(1 - discount_rate)


  discount_orders.append(new_orders)
  return discount_orders

discounted = apply_discount(Orders, 0.10 )
print(discounted)
# Out:
# [{'order_id': 100, 'customer': 'sidd', 'item': 'keyboard', 'quantity': 3, 'price_per_item': 4500.0, 'order_date': '2025-10-27'}]

# %% [markdown]
# ##3.2

# %%
count = 20
def show_numbers():
 number= 5
 print("inside function- local variable:", number)
 print("inside function- global variable:", count)

def change_global():
  global count
  count = 30
  print("global variable change inside function:", count)

show_numbers()
change_global()
# Out:
# inside function- local variable: 5
# inside function- global variable: 20
# global variable change inside function: 30

# %% [markdown]
# ## 4.1

# %%
class OrderIterator:
    def  __init__(self,orders):
      self.orders = orders
    def  __iter__(self):
      for order in self.orders:
        yield order

Orders = [
    {"order_id" :10, "customer": "aswathi",
     "item":"tv", "quantity":1,
     "price_per_item": 10000.0, "order_date":"2025-10-21"},
    {"order_id" :20, "customer": "anu",
     "item":"phone", "quantity":3,
     "price_per_item": 20000.0, "order_date":"2025-10-22"},
    {"order_id" :30, "customer": "Paul",
     "item":"laptop", "quantity":2,
     "price_per_item": 15000.0, "order_date":"2025-10-23"},
    {"order_id" :40, "customer": "Alice",
     "item":"phone", "quantity":1,
     "price_per_item": 18000.0, "order_date":"2025-10-2"},
    {"order_id" :50, "customer": "Arya",
     "item":"Headphones", "quantity":2,
     "price_per_item": 26000.0, "order_date":"2025-10-24"},
    {"order_id" :60, "customer": "David",
     "item":"keyboard", "quantity":2,
     "price_per_item": 19000.0, "order_date":"2025-10-25"},
    {"order_id" :70, "customer": "jack",
     "item":"USB cable", "quantity":1,
     "price_per_item": 290.0, "order_date":"2025-10-21"},
    {"order_id" :80, "customer": "julie",
     "item":"Monitar", "quantity":3,
     "price_per_item": 9000.0, "order_date":"2025-10-28"},
    {"order_id" :90, "customer": "Helen",
     "item":"Power bank", "quantity":1,
     "price_per_item": 45000.0, "order_date":"2025-10-23"},
    {"order_id" :100, "customer": "sidd",
     "item":"keyboard", "quantity":3,
     "price_per_item": 5000.0, "order_date":"2025-10-27"},
]

for order in OrderIterator(Orders):
  print(order)
# Out:
# {'order_id': 10, 'customer': 'aswathi', 'item': 'tv', 'quantity': 1, 'price_per_item': 10000.0, 'order_date': '2025-10-21'}
# {'order_id': 20, 'customer': 'anu', 'item': 'phone', 'quantity': 3, 'price_per_item': 20000.0, 'order_date': '2025-10-22'}
# {'order_id': 30, 'customer': 'Paul', 'item': 'laptop', 'quantity': 2, 'price_per_item': 15000.0, 'order_date': '2025-10-23'}
# {'order_id': 40, 'customer': 'Alice', 'item': 'phone', 'quantity': 1, 'price_per_item': 18000.0, 'order_date': '2025-10-2'}
# {'order_id': 50, 'customer': 'Arya', 'item': 'Headphones', 'quantity': 2, 'price_per_item': 26000.0, 'order_date': '2025-10-24'}
# {'order_id': 60, 'customer': 'David', 'item': 'keyboard', 'quantity': 2, 'price_per_item': 19000.0, 'order_date': '2025-10-25'}
# {'order_id': 70, 'customer': 'jack', 'item': 'USB cable', 'quantity': 1, 'price_per_item': 290.0, 'order_date': '2025-10-21'}
# ...

# %% [markdown]
# ##4.2

# %%
me

# %%
orders_by_customer = {}
for order in Orders:
  name = order["customer"]

  if name not in orders_by_customer:
    orders_by_customer[name]= []

    orders_by_customer[name].append(order)

print(orders_by_customer)
# Out:
# {'aswathi': [{'order_id': 10, 'customer': 'aswathi', 'item': 'tv', 'quantity': 1, 'price_per_item': 10000.0, 'order_date': '2025-10-21'}], 'anu': [{'order_id': 20, 'customer': 'anu', 'item': 'phone', 'quantity': 3, 'price_per_item': 20000.0, 'order_date': '2025-10-22'}], 'Paul': [{'order_id': 30, 'customer': 'Paul', 'item': 'laptop', 'quantity': 2, 'price_per_item': 15000.0, 'order_date': '2025-10-23'}], 'Alice': [{'order_id': 40, 'customer': 'Alice', 'item': 'phone', 'quantity': 1, 'price_per_item': 18000.0, 'order_date': '2025-10-2'}], 'Arya': [{'order_id': 50, 'customer': 'Arya', 'item': 'Headphones', 'quantity': 2, 'price_per_item': 26000.0, 'order_date': '2025-10-24'}], 'David': [{'order_id': 60, 'customer': 'David', 'item': 'keyboard', 'quantity': 2, 'price_per_item': 19000.0, 'order_date': '2025-10-25'}], 'jack': [{'order_id': 70, 'customer': 'jack', 'item': 'USB cable', 'quantity': 1, 'price_per_item': 290.0, 'order_date': '2025-10-21'}], 'julie': [{'order_id': 80, 'customer'
# ...
